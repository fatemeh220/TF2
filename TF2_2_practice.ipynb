# %% [markdown]
# **CV2**

# %%
import cv2

*******************

print(image)
print(type(image))

# %%
print("Shape:", image.shape)
print("Data type:", image.dtype)
print("Minimum value:", image.min())
print("Maximum value:", image.max())

# %%
import cv2
import matplotlib.pyplot as plt

image = cv2.imread("astronaut.png")

plt.imshow(image)
plt.axis("off")
plt.show()

# %%
*******************

plt.imshow(image_rgb)
plt.axis("off")
plt.show()

# %%
import matplotlib.pyplot as plt

image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

plt.figure(figsize=(6, 6))
plt.imshow(image_rgb)
plt.axis("off")
plt.show()

# %%
cv2.imshow("Image", image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
pixel = image[100, 200]

print(pixel)

# %%
# unpack it:

b, g, r = image[100, 200]

print("Blue:", b)
print("Green:", g)
print("Red:", r)

# %%
image_copy = image.copy()

*******************

# %%
# A whole region is more visible:

image_copy = image.copy()

*******************

image_copy_rgb = cv2.cvtColor(image_copy, cv2.COLOR_BGR2RGB)

plt.imshow(image_copy_rgb)
plt.axis("off")
plt.show()

# %%
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

print("Color shape:", image.shape)
print("Gray shape:", gray.shape)

plt.imshow(gray, cmap="gray")
plt.axis("off")
plt.show()

# %%
*******************

print("Original:", image.shape)
print("Resized:", resized.shape)

# %%
# Display
resized_rgb = cv2.cvtColor(resized, cv2.COLOR_BGR2RGB)

plt.imshow(resized_rgb)
plt.axis("off")
plt.show()

# %%
crop = image[100:350, 150:400]

crop_rgb = cv2.cvtColor(crop, cv2.COLOR_BGR2RGB)

plt.imshow(crop_rgb)
plt.axis("off")
plt.show()

# %%
horizontal = cv2.flip(image, 1)
*******************
both = cv2.flip(image, -1)

# %%
# Convert flipped images to RGB
horizontal_rgb = cv2.cvtColor(horizontal, cv2.COLOR_BGR2RGB)
vertical_rgb = cv2.cvtColor(vertical, cv2.COLOR_BGR2RGB)
both_rgb = cv2.cvtColor(both, cv2.COLOR_BGR2RGB)

# Show all images
fig, axes = plt.subplots(2, 2, figsize=(10, 8))

axes[0, 0].imshow(image_rgb)
axes[0, 0].set_title("Original")

axes[0, 1].imshow(horizontal_rgb)
axes[0, 1].set_title("Horizontal Flip: cv2.flip(image, 1)")

axes[1, 0].imshow(vertical_rgb)
axes[1, 0].set_title("Vertical Flip: cv2.flip(image, 0)")

axes[1, 1].imshow(both_rgb)
axes[1, 1].set_title("Both Directions: cv2.flip(image, -1)")

for ax in axes.ravel():
    ax.axis("off")

plt.tight_layout()
plt.show()

# %%
*******************

# %% [markdown]
# **PIL**

# %%
*******************

image = Image.open("astronaut.png")

print(image)
print(type(image))

# %%
print("Size:", image.size)
print("Mode:", image.mode)
print("Format:", image.format)

# %%
image.show()

# %%
import matplotlib.pyplot as plt

plt.imshow(image)
plt.axis("off")
plt.show()

# %%
gray = image.convert("L")

print(gray.mode)

plt.imshow(gray, cmap="gray")
plt.axis("off")
plt.show()

# %%
rgba = image.convert("RGBA")

print(rgba.mode)

plt.imshow(rgba)
plt.axis("off")
plt.show()

# %%
rgba = image.convert("RGBA")

# Change the alpha channel
*******************

plt.imshow(rgba)
plt.axis("off")
plt.show()

# %%
*******************

print("Original:", image.size)
print("Resized:", resized.size)

plt.imshow(resized)
plt.axis("off")
plt.show()

# %%
*******************

plt.imshow(crop)
plt.axis("off")
plt.show()

# %%
rotated = image.rotate(45)

plt.imshow(rotated)
plt.axis("off")
plt.show()

# %%
*******************

plt.imshow(rotated)
plt.axis("off")
plt.show()

# %%
horizontal = image.transpose(Image.Transpose.FLIP_LEFT_RIGHT)
*******************

# %%
fig, axes = plt.subplots(1, 3, figsize=(12, 4))

axes[0].imshow(image)
axes[0].set_title("Original")

axes[1].imshow(horizontal)
axes[1].set_title("Horizontal Flip")

axes[2].imshow(vertical)
axes[2].set_title("Vertical Flip")

for ax in axes:
    ax.axis("off")

plt.tight_layout()
plt.show()

# %%
resized.save("resized_astronaut.png")

# %%
from skimage import data
import matplotlib.pyplot as plt

image = data.astronaut()

plt.imshow(image)
plt.axis("off")
plt.show()

print(image.shape)
print(image.dtype)

# %%
*******************
import matplotlib.pyplot as plt

images = {
    "astronaut": data.astronaut(),
    "camera": data.camera(),
    "coins": data.coins(),
    "coffee": data.coffee(),
    "chelsea": data.chelsea(),
    "moon": data.moon(),
    "clock": data.clock(),
    "page": data.page(),
    "text": data.text(),
    "rocket": data.rocket(),
    "horse": data.horse(),
    "hubble": data.hubble_deep_field(),
    "immunohistochemistry": data.immunohistochemistry(),
}

fig, axes = plt.subplots(4, 4, figsize=(14, 14))
axes = axes.ravel()

for ax, (name, img) in zip(axes, images.items()):
    if img.ndim == 2:
        ax.imshow(img, cmap="gray")
    else:
        ax.imshow(img)

    ax.set_title(f"{name}\nshape={img.shape}", fontsize=10)
    ax.axis("off")

# Hide unused subplot cells
for ax in axes[len(images):]:
    ax.axis("off")

plt.tight_layout()
plt.show()

# %%
from skimage import data
from PIL import Image

image = data.astronaut()

Image.fromarray(image).save("astronaut.png")

# %%
from skimage import color, data

image = data.astronaut()
*******************

print(gray.shape)
print(gray.dtype)
print(gray.min(), gray.max())

plt.imshow(gray, cmap="gray")
plt.axis("off")
plt.show()

# %%
from skimage import filters

*******************

plt.imshow(edges, cmap="gray")
plt.axis("off")
plt.title("Sobel Edges")
plt.show()

# %%
*******************
mask = gray > threshold

print("Threshold:", threshold)

plt.imshow(mask, cmap="gray")
plt.axis("off")
plt.title("Binary Mask")
plt.show()

# %% [markdown]
# **TensorFlow**

# %%
import tensorflow as tf

img = tf.keras.utils.load_img("astronaut.png")
arr = tf.keras.utils.img_to_array(img)

print("Image type:", type(img))
print("Array type:", type(arr))
print("Shape:", arr.shape)
print("Dtype:", arr.dtype)

# %%
import matplotlib.pyplot as plt

plt.imshow(img)
plt.axis("off")
plt.show()

# %%
plt.imshow(arr.astype("uint8"))
plt.axis("off")
plt.show()

# %%
import tensorflow as tf
import matplotlib.pyplot as plt

image_path = "astronaut.png"

*******************
*******************

print(type(image))
print(image.shape)
print(image.dtype)

# %%
plt.imshow(image)
plt.axis("off")
plt.show()

# %%
print("Shape:", image.shape)
print("Dtype:", image.dtype)

print("Minimum:", tf.reduce_min(image).numpy())
print("Maximum:", tf.reduce_max(image).numpy())

# %%
*******************

image_normalized = image_resized / 255.0

print("Shape:", image_normalized.shape)
print("Dtype:", image_normalized.dtype)
print("Min:", tf.reduce_min(image_normalized).numpy())
print("Max:", tf.reduce_max(image_normalized).numpy())

# %%
img_float = tf.cast(image, tf.float32)

mean = tf.reduce_mean(img_float)
std = tf.math.reduce_std(img_float)

img_std = (img_float - mean) / (std + 1e-7)

print("Original mean:", mean.numpy())
print("Original std:", std.numpy())

print("Standardized mean:", tf.reduce_mean(img_std).numpy())
print("Standardized std:", tf.math.reduce_std(img_std).numpy())

print("Min:", tf.reduce_min(img_std).numpy())
print("Max:", tf.reduce_max(img_std).numpy())

# %%
batch = tf.expand_dims(image_normalized, axis=0)

print(batch.shape)

# %%
def load_preprocess_image(path, size=(224, 224)):
    image_bytes = tf.io.read_file(path)
    image = tf.image.decode_image(image_bytes, channels=3)
    image = tf.image.resize(image, size)
    image = image / 255.0
    return image

image = load_preprocess_image("astronaut.png")

print(image.shape)
print(image.dtype)

# %%
data_augmentation = tf.keras.Sequential([
    tf.keras.layers.RandomFlip("horizontal"),
    tf.keras.layers.RandomRotation(0.1),
    tf.keras.layers.RandomZoom(0.1),
])

# %%
image_batch = tf.expand_dims(image_normalized, axis=0)

*******************

plt.imshow(augmented[0])
plt.axis("off")
plt.show()

# %%
fig, axes = plt.subplots(2, 4, figsize=(12, 6))

for ax in axes.ravel():
    augmented = data_augmentation(image_batch, training=True)
    ax.imshow(augmented[0])
    ax.axis("off")

plt.tight_layout()
plt.show()

# %%
data_augmentation = tf.keras.Sequential([
    tf.keras.layers.RandomFlip("horizontal"),
    tf.keras.layers.RandomRotation(0.1),
    tf.keras.layers.RandomZoom(0.1),
    tf.keras.layers.RandomBrightness(0.2),
])

# %% [markdown]
# **Pytorch**

# %%
import torch
from PIL import Image
import matplotlib.pyplot as plt
from torchvision import transforms

image = Image.open("astronaut.png").convert("RGB")
print(type(image))

# %%
transform = transforms.ToTensor()

tensor = transform(image)

print(tensor.shape)
print(tensor.dtype)
print(tensor.min())
print(tensor.max())

# %%
resized_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor()
])

tensor = resized_transform(image)

print("Tensor shape:", tensor.shape)

# %%
*******************

plt.imshow(image_for_display)
plt.axis("off")
plt.show()

# %%
batch = tensor.unsqueeze(0)

print(batch.shape)
